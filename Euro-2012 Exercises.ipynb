# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
from numpy import nan as na

# %% [markdown]
# ### Step 2. Import the dataset Euro_2012_stats_TEAM

# %% [markdown]
# ### Step 3. Assign it to a variable called euro12.

# %%
euro12=pd.read_csv("C:/Users/Haroon Traders/Desktop/Assignment-2/Euro_2012_stats_TEAM.csv")
euro12
# Out:
#                                                  Team  Goals  Shots on target  \
# 0                                             Croatia    4.0             13.0
# 1                                      Czech Republic    4.0             13.0
# 2                                             Denmark    4.0             10.0
# 3                                             England    5.0             11.0
# 4                                              France    3.0             22.0
# 5                                             Germany   10.0             32.0
# 6                                              Greece    5.0              8.0
# 7                                               Italy    6.0             34.0
# 8                                         Netherlands    2.0             12.0
# 9                                              Poland    2.0             15.0
# 10                                           Portugal    6.0             22.0
# ...

# %% [markdown]
# ### Step 4. Select only the Goal column.

# %%
dic=dict(euro12)
dic['Goals']
# Out:
# 0      4.0
# 1      4.0
# 2      4.0
# 3      5.0
# 4      3.0
# 5     10.0
# 6      5.0
# 7      6.0
# 8      2.0
# 9      2.0
# 10     6.0
# 11     1.0
# 12     5.0
# 13    12.0
# 14     5.0
# 15     2.0
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# Name: Goals, dtype: float64

# %% [markdown]
# ### Step 5. How many team participated in the Euro2012?

# %%
teams=dic['Team']
teams.count()
# Out:
# 17

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
for x in dic.keys():
    print(x)
# Out:
# Team
# Goals
# Shots on target
# Shots off target
# Shooting Accuracy
# % Goals-to-shots
# Total shots (inc. Blocked)
# Hit Woodwork
# Penalty goals
# Penalties not scored
# Headed goals
# Passes
# Passes completed
# Passing Accuracy
# Touches
# Crosses
# Dribbles
# Corners Taken
# Tackles
# Clearances
# Interceptions
# Clearances off line
# Clean Sheets
# Blocks
# Goals conceded
# Saves made
# Saves-to-shots ratio
# Fouls Won
# Fouls Conceded
# Offsides
# Yellow Cards
# Red Cards
# Subs on
# Subs off
# Players Used

# %% [markdown]
# ### Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
team=dic['Team']
yellow=dic['Yellow Cards'] 
red=dic['Red Cards']
dic_final={'Teams':team,'yellow':yellow,'red':red}
discipline=pd.DataFrame(dic_final)
discipline
# Out:
#                                                 Teams  yellow  red
# 0                                             Croatia     9.0  0.0
# 1                                      Czech Republic     7.0  0.0
# 2                                             Denmark     4.0  0.0
# 3                                             England     5.0  0.0
# 4                                              France     6.0  0.0
# 5                                             Germany     4.0  0.0
# 6                                              Greece     9.0  1.0
# 7                                               Italy    16.0  0.0
# 8                                         Netherlands     5.0  0.0
# 9                                              Poland     7.0  1.0
# 10                                           Portugal    12.0  0.0
# 11                                Republic of Ireland     6.0  1.0
# 12                                             Russia     6.0  0.0
# ...

# %% [markdown]
# ### Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %%
a=discipline.sort_values('red')
#b=discipline.sort_values('Teams')
c=discipline.sort_values('yellow')
print(a)
print(c)
# Out:
#                                                 Teams  yellow  red
# 0                                             Croatia     9.0  0.0
# 1                                      Czech Republic     7.0  0.0
# 2                                             Denmark     4.0  0.0
# 3                                             England     5.0  0.0
# 4                                              France     6.0  0.0
# 5                                             Germany     4.0  0.0
# 7                                               Italy    16.0  0.0
# 8                                         Netherlands     5.0  0.0
# 10                                           Portugal    12.0  0.0
# 12                                             Russia     6.0  0.0
# 13                                              Spain    11.0  0.0
# 14                                             Sweden     7.0  0.0
# 15                                            Ukraine     5.0  0.0
# ...

# %% [markdown]
# ### Step 9. Calculate the mean Yellow Cards given per Team

# %%
listt=discipline['yellow']
res=pd.Series(listt)
right=res.fillna(0)
res=right.values
#add=0
#for x in res:
#    add=add+x
#add=res.sum()
m=res.mean()
m
# Out:
# 5.95

# %% [markdown]
# ### Step 10. Filter teams that scored more than 6 goals

# %%
team=dic['Team']
goal=dic['Goals']
dic_filter={'Teams':team,'goals':goal}
filter_df=pd.DataFrame(dic_filter)
#ab=filter_df['goals'].values>6
team_filter=filter_df['Teams'].values
for v in range(0,len(team_filter)):
    if filter_df['goals'][v]>6:
        print(filter_df['Teams'][v])
# Out:
# Germany
# Spain

# %% [markdown]
# ### Step 11. Select the teams that start with G

# %%
for _v in range(0,len(team_filter)):
    if filter_df['Teams'][_v][0]=="G":
        print(filter_df['Teams'][_v])
# Out:
# Germany
# Greece
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-8f561048fecf> in <module>
#       1 for _v in range(0,len(team_filter)):
# ----> 2     if filter_df['Teams'][_v][0]=="G":
#       3         print(filter_df['Teams'][_v])
#
# TypeError: 'float' object is not subscriptable

# %% [markdown]
# ### Step 12. Select the first 7 columns

# %%
main_df=pd.DataFrame(dic)
l=main_df.columns
for f in range(0,7):
    print(l[f])
# Out:
# Team
# Goals
# Shots on target
# Shots off target
# Shooting Accuracy
# % Goals-to-shots
# Total shots (inc. Blocked)

# %% [markdown]
# ### Step 13. Select all columns except the last 3.

# %%
main_df=pd.DataFrame(dic)
l=main_df.columns
for f in range(0,len(l)-3):
    print(l[f])
# Out:
# Team
# Goals
# Shots on target
# Shots off target
# Shooting Accuracy
# % Goals-to-shots
# Total shots (inc. Blocked)
# Hit Woodwork
# Penalty goals
# Penalties not scored
# Headed goals
# Passes
# Passes completed
# Passing Accuracy
# Touches
# Crosses
# Dribbles
# Corners Taken
# Tackles
# Clearances
# Interceptions
# Clearances off line
# Clean Sheets
# Blocks
# Goals conceded
# Saves made
# Saves-to-shots ratio
# Fouls Won
# Fouls Conceded
# Offsides
# Yellow Cards
# Red Cards

# %% [markdown]
# ### Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %% [markdown]
# ### Step 15. Use apply method on Goal Column to make a new column called Performance, using following conditions
#
# 1. If Goals are less than or equal to 2, peformance is **Below Avg**
# 2. If Goals are more than 2 and less than or equal to 5, peformance is **Average**
# 3. If Goals are more than 5 and less than or equal to 10, peformance is **Above Average**
# 4. If Goals are more than 10 then peformance is **Excellent**

# %%
goal_col=main_df['Goals']
def performance_checker(x):
    if x<=2:
        perf="bellow avg"
    elif x>2 and x<=5:
        perf="average"
    elif x>5 and x<=10:
        perf="above average"
    elif x>10:
        perf="excellent"
    else:
        perf="invalid-default case"
    return perf
#ab=goal_col.apply(performance_checker(goal_col[0]))
#print(ab)
print
for x in range(0,len(goal_col)):
    print(performance_checker(goal_col[x]))
# Out:
# nan
# average
# average
# average
# average
# average
# above average
# average
# above average
# bellow avg
# bellow avg
# above average
# bellow avg
# average
# excellent
# average
# bellow avg
# invalid-default case
# invalid-default case
# invalid-default case
# invalid-default case
